# %%
import pandas as pd

# %% [markdown]
# To use excel:
# install xlrd ;
# install openpyxl

# %%
xlsfile = pd.ExcelFile('buritodata .xlsx')

# %% [markdown]
# Once the excel file is loaded parse the sheet name

# %%
df = xlsfile.parse('buritodata (1)')

# %%
df
# Out:
#      store  month  sqft     rent  overhead  empl  laborcost  othercost  \
# 0        1      1  2710  3426.90      1100    25    7203.51      12519
# 1        1      2  2710  3426.90      1100    26    6534.12      12938
# 2        1      3  2710  3426.90      1100    26    5640.78      12812
# 3        1      4  2710  3426.90      1100    31    9123.81      12881
# 4        1      5  2710  3426.90      1100    30    9364.10      12597
# 5        1      6  2710  3426.90      1100    31    8924.29      12452
# 6        1      7  2710  3426.90      1100    33   10128.89      13001
# 7        1      8  2710  3426.90      1100    29    9861.04      13055
# 8        1      9  2710  3426.90      1100    32    7340.39      12636
# 9        1     10  2710  3426.90      1100    33    9352.21      12714
# 10       1     11  2710  3426.90      1100    31    8611.54      12319
# 11       1     12  2710  3426.90      1100    31   10478.89      12760
# ...

# %%
df.head()
# Out:
#    store  month  sqft    rent  overhead  empl  laborcost  othercost  orders  \
# 0      1      1  2710  3426.9      1100    25    7203.51      12519    6169
# 1      1      2  2710  3426.9      1100    26    6534.12      12938    6200
# 2      1      3  2710  3426.9      1100    26    5640.78      12812    6200
# 3      1      4  2710  3426.9      1100    31    9123.81      12881    6351
# 4      1      5  2710  3426.9      1100    30    9364.10      12597    6321
#
#    avgrev_order   revenue
# 0         10.66  68470.54
# 1          9.85  63813.00
# 2          9.72  62980.00
# 3          8.40  56078.40
# 4          8.79  58312.59

# %%
df.describe()
# Out:
#             store       month         sqft         rent     overhead  \
# count  372.000000  372.000000   372.000000   372.000000   372.000000
# mean    16.000000    6.500000  2686.774194  3285.792258  1087.096774
# std      8.956318    3.456702   379.740758   482.210662   168.216140
# min      1.000000    1.000000  2030.000000  2279.180000   900.000000
# 25%      8.000000    3.750000  2350.000000  2839.070000   900.000000
# 50%     16.000000    6.500000  2690.000000  3373.160000  1100.000000
# 75%     24.000000    9.250000  2970.000000  3663.620000  1100.000000
# max     31.000000   12.000000  3430.000000  4052.720000  1500.000000
#
#              empl     laborcost     othercost       orders  avgrev_order  \
# count  372.000000    372.000000    372.000000   372.000000    372.000000
# mean    28.137097  10192.653172  12699.465054  6218.083333      9.081989
# std      5.037864   4031.041232    418.856409   838.116134      0.913476
# ...
