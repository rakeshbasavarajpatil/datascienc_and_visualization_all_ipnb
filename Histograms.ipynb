# %% [markdown]
# http://stanford.edu/~mwaskom/software/seaborn/installing.html

# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#stats
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'

# %%
d1 = randn(100)

# %%
plt.hist(d1)
# Out:
# (array([  5.,  13.,  14.,  17.,  11.,  10.,  17.,   7.,   3.,   3.]),
#  array([-1.65692703, -1.2463574 , -0.83578777, -0.42521814, -0.01464851,
#          0.39592112,  0.80649075,  1.21706037,  1.62763   ,  2.03819963,
#          2.44876926]),
#  <a list of 10 Patch objects>)

# %%
d2 = randn(80)

# %%
plt.hist(d2,color='indianred')
# Out:
# (array([  2.,   2.,   6.,   7.,   9.,  14.,  16.,  12.,   7.,   5.]),
#  array([-2.40772732, -1.96923692, -1.53074652, -1.09225612, -0.65376572,
#         -0.21527532,  0.22321508,  0.66170547,  1.10019587,  1.53868627,
#          1.97717667]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# alpha is for transparency

# %%
plt.hist(d1,normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(d2,normed=True,alpha=0.5,bins=20)
# Out:
# (array([ 0.11402758,  0.        ,  0.11402758,  0.        ,  0.17104137,
#          0.17104137,  0.17104137,  0.22805516,  0.34208275,  0.17104137,
#          0.34208275,  0.45611033,  0.39909654,  0.51312412,  0.45611033,
#          0.22805516,  0.28506896,  0.11402758,  0.11402758,  0.17104137]),
#  array([-2.40772732, -2.18848212, -1.96923692, -1.74999172, -1.53074652,
#         -1.31150132, -1.09225612, -0.87301092, -0.65376572, -0.43452052,
#         -0.21527532,  0.00396988,  0.22321508,  0.44246028,  0.66170547,
#          0.88095067,  1.10019587,  1.31944107,  1.53868627,  1.75793147,
#          1.97717667]),
#  <a list of 20 Patch objects>)

# %%
d3 = randn(1000)
d4 = randn(1000)

# %%
sns.jointplot(d3,d4)

# %%
sns.jointplot(d3,d4,kind='hex')
